# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
df = pd.read_csv("Ik_twitter_data.csv")

# %%
df.shape
# Out:
# (40, 39)

# %% [markdown]
# ### Grabing Only English tweets Data

# %%
english_tweets_data = df[df['language'] == 'en']
english_tweets_data.shape
# Out:
# (19, 39)

# %%
english_tweets_data.head(4)
# Out:
#    Unnamed: 0                   id      conversation_id    created_at  \
# 2           2  1578419867664777217  1578419863139549184  1.665160e+12
# 3           3  1578419863139549184  1578419863139549184  1.665160e+12
# 5           5  1577709095880167424  1577709095880167424  1.664990e+12
# 8           8  1577376975697625107  1577376972589645828  1.664911e+12
#
#                   date  timezone  place  \
# 2  2022-10-07 21:19:56       500    NaN
# 3  2022-10-07 21:19:55       500    NaN
# 5  2022-10-05 22:15:35       500    NaN
# 8  2022-10-05 00:15:51       500    NaN
#
#                                                tweet language hashtags  ...  \
# 2  Above all they have given themselves immunity ...       en       []  ...
# 3  Mianwali getting ready for the million people ...       en       []  ...
# 5  While our Ehsaas social welfare programmes wer...       en       []  ...
# 8  ABA number for wire transfer  113024009 In add...       en       []  ...
#
#   geo  source  user_rt_id user_rt retweet_id  reply_to  retweet_date  \
# 2 NaN     NaN         NaN     NaN        NaN        []           NaN
# 3 NaN     NaN         NaN     NaN        NaN        []           NaN
# 5 NaN     NaN         NaN     NaN        NaN        []           NaN
# 8 NaN     NaN         NaN     NaN        NaN        []           NaN
#
#   translate trans_src trans_dest
# 2       NaN       NaN        NaN
# 3       NaN       NaN        NaN
# 5       NaN       NaN        NaN
# 8       NaN       NaN        NaN
#
# [4 rows x 39 columns]

# %%
english_tweets_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'conversation_id', 'created_at', 'date', 'timezone',
#        'place', 'tweet', 'language', 'hashtags', 'cashtags', 'user_id',
#        'user_id_str', 'username', 'name', 'day', 'hour', 'link', 'urls',
#        'photos', 'video', 'thumbnail', 'retweet', 'nlikes', 'nreplies',
#        'nretweets', 'quote_url', 'search', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
#        'translate', 'trans_src', 'trans_dest'],
#       dtype='object')

# %% [markdown]
# ### Tweets data Only

# %%
en_tweets = english_tweets_data[['tweet']]

# %%
en_tweets.head(5)
# Out:
#                                                tweet
# 2  Above all they have given themselves immunity ...
# 3  Mianwali getting ready for the million people ...
# 5  While our Ehsaas social welfare programmes wer...
# 8  ABA number for wire transfer  113024009 In add...
# 9  I thank our overseas donors who waited patient...

# %% [markdown]
# ### Using NLTK for word tokenizing and stopwords removal

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# ### Applying word_tokenizer on tweets

# %%
sents = []
for sent in en_tweets.values:
    word = word_tokenize(sent[0])
    sents.append(word)

# %%
sents
# Out:
# [['Above',
#   'all',
#   'they',
#   'have',
#   'given',
#   'themselves',
#   'immunity',
#   'from',
#   'their',
#   'corruption',
#   'cases',
#   'worth',
#   '1100',
#   'billion',
#   '.'],
#  ['Mianwali',
#   'getting',
#   'ready',
#   'for',
#   'the',
#   'million',
#   'people',
#   'march',
#   'to',
#   'Islamabad',
#   '.',
#   'InshaAllah',
#   'it',
#   'will',
#   'be',
#   'the',
#   'greatest',
#   'protest',
#   'in',
#   'our',
#   'history',
#   'against',
#   'an',
#   'Imported',
#   'govt',
#   'of',
#   'crooks',
#   'who',
#   'have',
#   'bankrupted',
#   'the',
#   'economy',
#   '&',
#   'amp',
#   ';',
#   'crushed',
#   'the',
#   'people',
#   'under',
#   'unprecedented',
#   'inflation',
#   '.',
#   'https',
#   ':',
#   '//t.co/Jb7I7ev7ZL'],
#  ['While',
#   'our',
#   'Ehsaas',
#   'social',
#   'welfare',
#   'programmes',
#   'were',
#   'being',
#   'appreciated',
#   'internationally',
#   ',',
#   'under',
#   'Imported',
#   'govt',
#   'all',
#   'our',
#   'efforts',
#   'to',
#   'make',
#   'Pak',
#   'a',
#   'welfare',
#   'state',
#   'are',
#   'being',
#   'reversed',
#   '.',
#   'Most',
#   'shocking',
#   'is',
#   'Maryam',
#   "'s",
#   'instruction',
#   'to',
#   'SS',
#   'to',
#   'stop',
#   'funding',
#   'the',
#   'health',
#   'insurance',
#   'card',
#   '.',
#   'https',
#   ':',
#   '//t.co/Y3gwS1iPxB'],
#  ['ABA',
#   'number',
#   'for',
#   'wire',
#   'transfer',
#   '113024009',
#   'In',
#   'addition',
#   'to',
#   'the',
#   'newly',
#   'established',
#   'foundation',
#   ',',
#   'we',
#   'will',
#   'continue',
#   'to',
#   'receive',
#   'funds',
#   'into',
#   'accounts',
#   'set',
#   'up',
#   'by',
#   'respective',
#   'CMs',
#   'of',
#   'Punjab',
#   '&',
#   'amp',
#   ';',
#   'Khyber',
#   'Pakhtunkhwa',
#   '.',
#   'The',
#   'several',
#   'ways',
#   'in',
#   'which',
#   'you',
#   'can',
#   'donate',
#   'are',
#   'outlined',
#   'here',
#   ':',
#   'https',
#   ':',
#   '//t.co/3styOIlfaW'],
#  ['I',
#   'thank',
#   'our',
#   'overseas',
#   'donors',
#   'who',
#   'waited',
#   'patiently',
#   'while',
#   'we',
#   'were',
#   'setting',
#   'up',
#   'an',
#   'account',
#   'to',
#   'facilitate',
#   'flood-relief',
#   'donations',
#   '.',
#   'Details',
#   'as',
#   'follows',
#   ':',
#   'Title',
#   ':',
#   'Insaf',
#   'Relief',
#   'Foundation',
#   'No',
#   '.',
#   '7004109',
#   'Southwestern',
#   'National',
#   'Bank',
#   ';',
#   '2951',
#   'West',
#   'Ball',
#   'Road',
#   ',',
#   'Suite',
#   '100',
#   'Anaheim',
#   ',',
#   'CA',
#   '92804',
#   'tel:714-822-6101'],
#  ['I',
#   'also',
#   'want',
#   'to',
#   'thank',
#   'millions',
#   'of',
#   'donors',
#   '&',
#   'amp',
#   ';',
#   'supporters',
#   'who',
#   'make',
#   'it',
#   'possible',
#   'for',
#   'us',
#   'to',
#   'continue',
#   'providing',
#   'world',
#   'class',
#   'cancer',
#   'treatment',
#   'completely',
#   'free',
#   'of',
#   'charge',
#   'to',
#   'over',
#   '75',
#   '%',
#   'of',
#   'our',
#   'patients',
#   '.',
#   'I',
#   'have',
#   'always',
#   'said',
#   'there',
#   'is',
#   'nothing',
#   'we',
#   'ca',
#   "n't",
#   'achieve',
#   'as',
#   'a',
#   'nation',
#   ',',
#   'if',
#   'we',
#   'put',
#   'our',
#   'minds',
#   'to',
#   'it',
#   '.'],
#  ['as',
#   'well',
#   'as',
#   'our',
#   'diagnostic',
#   'centres',
#   'in',
#   'Karachi',
#   '&',
#   'amp',
#   ';',
#   'Lahore',
#   'have',
#   'all',
#   'been',
#   'awarded',
#   'the',
#   'JCI',
#   '’',
#   's',
#   'Gold',
#   'Seal',
#   'of',
#   'Approval',
#   ',',
#   'the',
#   'global',
#   'gold',
#   'standard',
#   'for',
#   'excellence',
#   'in',
#   'quality',
#   'healthcare',
#   '.',
#   'I',
#   'want',
#   'to',
#   'thank',
#   'the',
#   'thousands',
#   'of',
#   'people',
#   'who',
#   'work',
#   'at',
#   'Shaukat',
#   'Khanum',
#   'for',
#   'their',
#   'hard',
#   'work',
#   'and',
#   'dedication',
#   '.'],
#  ['I',
#   'am',
#   'delighted',
#   'to',
#   'announce',
#   'that',
#   'Shaukat',
#   'Khanum',
#   'has',
#   'become',
#   'only',
#   'the',
#   'second',
#   'organisation',
#   'in',
#   'the',
#   'world',
#   'to',
#   'be',
#   'awarded',
#   'full',
#   'Enterprise',
#   'Accreditation',
#   'by',
#   'the',
#   'Joint',
#   'Commission',
#   'International',
#   '.',
#   'After',
#   'a',
#   'gruelling',
#   'three-week',
#   'survey',
#   'in',
#   'Aug/Sept',
#   '2022',
#   ',',
#   'our',
#   'hospitals',
#   'in',
#   'Lahore',
#   '&',
#   'amp',
#   ';',
#   'Peshawar',
#   ','],
#  ['Congratulations',
#   'to',
#   'Crown',
#   'Prince',
#   'Mohammed',
#   'bin',
#   'Salman',
#   'on',
#   'being',
#   'appointed',
#   'Prime',
#   'Minister',
#   'of',
#   'the',
#   'Kingdom',
#   'of',
#   'Saudi',
#   'Arabia',
#   '.',
#   'Your',
#   'friendship',
#   '&',
#   'amp',
#   ';',
#   'support',
#   'for',
#   'Pakistan',
#   'is',
#   'invaluable',
#   'and',
#   'with',
#   'your',
#   'vision',
#   'you',
#   'will',
#   'usher',
#   'the',
#   'Kingdom',
#   'into',
#   'a',
#   'new',
#   'era',
#   '.'],
#  ['Tragic',
#   'army',
#   'heli',
#   'crash',
#   'in',
#   'which',
#   '6',
#   'soldiers',
#   'were',
#   'martyred',
#   ',',
#   'near',
#   'Khost',
#   ',',
#   'Harnai',
#   'Balochistan',
#   '.',
#   'My',
#   'deepest',
#   'condolences',
#   'and',
#   'prayers',
#   'go',
#   'to',
#   'the',
#   'families',
#   'of',
#   'these',
#   'brave',
#   'soldiers',
#   '.'],
#  ['Crime',
#   'Minister',
#   'discussing',
#   'appt',
#   'of',
#   'COAS',
#   '&',
#   'amp',
#   ';',
#   'any',
#   'other',
#   'state',
#   'matter',
#   'with',
#   'convict',
#   'Nawaz',
#   'Sharif',
#   '&',
#   'amp',
#   ';',
#   'Ministers',
#   'declaring',
#   'they',
#   'will',
#   'appt',
#   'COAS',
#   'after',
#   'consulting',
#   'Nawaz',
#   'Sharif',
#   'are',
#   'all',
#   'in',
#   'contravention',
#   'not',
#   'only',
#   'of',
#   'the',
#   'Official',
#   'Secrets',
#   'Act',
#   '(',
#   'section',
#   '5:1',
#   ')',
#   'but',
#   'also',
#   'of',
#   'their',
#   'oaths',
#   'of',
#   'office',
#   '.',
#   'https',
#   ':',
#   '//t.co/bYH5ca971j'],
#  ['Thank',
#   'you',
#   'Chakwal',
#   'for',
#   'the',
#   'record',
#   'turnout',
#   'today',
#   'at',
#   'my',
#   'Haqiqi',
#   'Azadi',
#   'jalsa',
#   '.',
#   'I',
#   'have',
#   'asked',
#   'my',
#   'nation',
#   'to',
#   'smash',
#   'the',
#   'idol',
#   'of',
#   'fear',
#   'through',
#   'which',
#   'this',
#   'imported',
#   'govt',
#   'of',
#   'crooks',
#   '(',
#   '60',
#   'percent',
#   'of',
#   'the',
#   'cabinet',
#   'is',
#   'on',
#   'bail',
#   ')',
#   'seeks',
#   'to',
#   'enslave',
#   'us',
#   '.',
#   'MashaAllah',
#   'our',
#   'nation',
#   'is',
#   'ready',
#   '.',
#   'https',
#   ':',
#   '//t.co/xOKtwZfBKS'],
#  ['including',
#   'three',
#   'barrages',
#   'conserving',
#   '270',
#   'bn',
#   'litres',
#   'of',
#   'water',
#   'for',
#   'much',
#   'needed',
#   'aquifer',
#   'of',
#   'Lahore',
#   '.',
#   'Rakh',
#   'Jhok',
#   ',',
#   'initiated',
#   'last',
#   'yr',
#   ',',
#   'is',
#   'part',
#   'of',
#   '5000',
#   'acres',
#   'of',
#   'reforestation',
#   'environment',
#   'plan',
#   '.',
#   'Embankments',
#   'will',
#   'be',
#   'built',
#   'with',
#   'innovative',
#   'method',
#   'of',
#   'using',
#   'natural',
#   'soil',
#   'to',
#   'prevent',
#   'flooding',
#   '.'],
#  ['Work',
#   'is',
#   'progressing',
#   'on',
#   'Ravi',
#   'city',
#   '.',
#   'With',
#   '$',
#   '40',
#   'bn',
#   'investment',
#   'portfolio',
#   'it',
#   'will',
#   'accommodate',
#   '15',
#   'mn',
#   'ppl',
#   '&',
#   'amp',
#   ';',
#   'will',
#   'be',
#   'Pak',
#   "'s",
#   'first',
#   'green',
#   '&',
#   'amp',
#   ';',
#   'smart',
#   'city',
#   '.',
#   'Vertical',
#   'riverfront',
#   'development',
#   'provides',
#   'range',
#   'of',
#   'opportunities',
#   'for',
#   'int',
#   '&',
#   'amp',
#   ';',
#   'national',
#   'investors',
#   '.',
#   'Ravi',
#   'City',
#   'will',
#   'have',
#   'world',
#   "'s",
#   'largest',
#   'waterfront',
#   'https',
#   ':',
#   '//t.co/XkFONVNlhf'],
#  ['@',
#   'CBDPunjab',
#   'tasked',
#   'with',
#   'converting',
#   'dead',
#   'capital',
#   'into',
#   'viable',
#   'transactions',
#   'channeling',
#   'wealth',
#   'generation',
#   'for',
#   'the',
#   'country',
#   '.',
#   'Similar',
#   'projects',
#   'with',
#   'immense',
#   'potential',
#   'will',
#   'be',
#   'launched',
#   'across',
#   'Punjab',
#   'leading',
#   'to',
#   'econ',
#   'growth',
#   '&',
#   'amp',
#   ';',
#   'prosperity',
#   'by',
#   'providing',
#   'multiple',
#   'opportunities',
#   'for',
#   'domestic',
#   '&',
#   'amp',
#   ';',
#   'FDI',
#   '.'],
#  ['Pak',
#   '’',
#   's',
#   '1st',
#   'central',
#   'business',
#   'district',
#   ',',
#   '@',
#   'CBDPunjab',
#   ',',
#   'will',
#   'accommodate',
#   '100+',
#   'vertical',
#   'developments',
#   'adding',
#   '600b+',
#   'to',
#   'country',
#   '’',
#   's',
#   'economy',
#   '.',
#   'To',
#   'compliment',
#   'futuristic',
#   'vertical',
#   'development',
#   ',',
#   'groundwork',
#   'will',
#   'commence',
#   'Oct',
#   "'22",
#   'on',
#   'Lhr',
#   '’',
#   's',
#   'Main',
#   'Blvd',
#   'reshaping',
#   'entire',
#   'infrastructure',
#   'of',
#   'the',
#   'vicinity',
#   '.',
#   'https',
#   ':',
#   '//t.co/x0f0AitRaT'],
#  ['Charsadda',
#   'jalsa',
#   'today',
#   'where',
#   'once',
#   'again',
#   'a',
#   'sea',
#   'of',
#   'people',
#   'responded',
#   'to',
#   'my',
#   'Haqiqi',
#   'Azadi',
#   'Tehreek',
#   '.',
#   'What',
#   'is',
#   'beyond',
#   'any',
#   'doubt',
#   'is',
#   'that',
#   'Pakistan',
#   'is',
#   'witnessing',
#   'a',
#   'revolution',
#   'unfolding',
#   '.',
#   'We',
#   'should',
#   'all',
#   'ensure',
#   'it',
#   'is',
#   'peaceful',
#   'and',
#   'through',
#   'the',
#   'ballot',
#   'box',
#   '.',
#   'https',
#   ':',
#   '//t.co/3WpEtvSmDI'],
#  ['What',
#   'we',
#   'left',
#   'behind',
#   '&',
#   'amp',
#   ';',
#   'how',
#   'the',
#   'Imported',
#   'Govt',
#   ',',
#   'brought',
#   'in',
#   'through',
#   'regime',
#   'change',
#   'conspiracy',
#   ',',
#   'has',
#   'wreaked',
#   'havoc',
#   'with',
#   'the',
#   'economy',
#   '.',
#   'https',
#   ':',
#   '//t.co/tcl3NuhehM'],
#  ['Imported',
#   'govt',
#   'is',
#   'completely',
#   'directionless',
#   '.',
#   'The',
#   'only',
#   'achievement',
#   'of',
#   'this',
#   'cabal',
#   'of',
#   'crooks',
#   'has',
#   'been',
#   'to',
#   'get',
#   'another',
#   'NRO',
#   'for',
#   'the',
#   'billions',
#   'they',
#   'looted',
#   'from',
#   'Pakistan',
#   '.',
#   'The',
#   'question',
#   'the',
#   'whole',
#   'nation',
#   'is',
#   'asking',
#   'is',
#   ':',
#   'Who',
#   'is',
#   'responsible',
#   'for',
#   'this',
#   'conspiracy',
#   'against',
#   'Pakistan',
#   '?']]

# %% [markdown]
# ### Removing Stops Words

# %%
stop_words = set(stopwords.words('english'))
filtered_sent = []
for w in sents:
    for word in w:
        if not word.lower() in stop_words:
            filtered_sent.append(word)

# %%
for word in filtered_sent:
    print(word)
# Out:
# given
# immunity
# corruption
# cases
# worth
# 1100
# billion
# .
# Mianwali
# getting
# ready
# million
# people
# march
# Islamabad
# .
# InshaAllah
# greatest
# protest
# history
# Imported
# govt
# crooks
# bankrupted
# economy
# &
# amp
# ;
# crushed
# people
# unprecedented
# inflation
# .
# https
# :
# //t.co/Jb7I7ev7ZL
# Ehsaas
# social
# welfare
# programmes
# appreciated
# internationally
# ,
# Imported
# govt
# efforts
# make
# Pak
# welfare
# state
# reversed
# .
# shocking
# Maryam
# 's
# instruction
# SS
# stop
# funding
# health
# insurance
# card
# .
# https
# :
# //t.co/Y3gwS1iPxB
# ABA
# number
# wire
# transfer
# 113024009
# addition
# newly
# established
# foundation
# ,
# continue
# receive
# funds
# accounts
# set
# Ravi
# City
# world
# 's
# largest
# waterfront
# https
# :
# //t.co/XkFONVNlhf
# @
# CBDPunjab
# tasked
# converting
# dead
# capital
# viable
# transactions
# channeling
# wealth
# generation
# country
# .
# Similar
# projects
# immense
# potential
# launched
# across
# Punjab
# leading
# econ
# growth
# &
# amp
# ;
# prosperity
# providing
# multiple
# opportunities
# domestic
# &
# amp
# ;
# FDI
# .
# Pak
# ’
# 1st
# central
# business
# district
# ,
# @
# CBDPunjab
# ,
# accommodate
# 100+
# vertical
# developments
# adding
# 600b+
# country
# ’
# economy
# .
# compliment
# futuristic
# vertical
# development
# ,
# groundwork
# commence
# Oct
# '22
# Lhr
# ’
# Main
# Blvd
# reshaping
# entire
# infrastructure
# vicinity
# .
# https
# :
# //t.co/x0f0AitRaT
# Charsadda
# jalsa
# today
# sea
# people
# responded
# Haqiqi
# Azadi
# Tehreek
# .
# beyond
# doubt
# Pakistan
# witnessing
# revolution
# unfolding
# .
# ensure
# peaceful
# ballot
# box
# .
# https
# :
# //t.co/3WpEtvSmDI
# left
# behind
# &
# amp
# ;
# Imported
# Govt
# ,
# brought
# regime
# change
# conspiracy
# ,
# wreaked
# havoc
# economy
# .
# https
# :
# //t.co/tcl3NuhehM
# Imported
# govt
# completely
# directionless
# .
# achievement
# cabal
# crooks
# get
# another
# NRO
# billions
# looted
# Pakistan
# .
# question
# whole
# nation
# asking
# :
# responsible
# conspiracy
# Pakistan
# ?

# %% [markdown]
# ## Using Spacy to apply NER and Lematization

# %%
import spacy
import re

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = ""
for w in filtered_sent:
    text= text + w + " "

text2 = ""
for i in re.findall("[a-zA-Z]*",text):
    if i != "":
        text2 = text2+i + " "

# %%
doc = nlp(text2)
label = [(X.text,X.label_) for X in doc.ents]
df4 = pd.DataFrame(label,columns = ['Word','Entity'])
df5 = df4[df4['Entity'] == "ORG"]
df6 = df5['Word'].value_counts()

# %% [markdown]
# ### Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
V_data = df6
plt.figure(figsize =(10,5))
sns.barplot(V_data.values,V_data.index,alpha=0.8)
plt.title("Top Organization Mentioned")
plt.ylabel("Words from Tweets",fontsize=12)
plt.xlabel('Word Counts',fontsize=12)
plt.show()
# Out:
# C:\Users\munir\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
en_tweets.head(5)
# Out:
#                                                tweet
# 2  Above all they have given themselves immunity ...
# 3  Mianwali getting ready for the million people ...
# 5  While our Ehsaas social welfare programmes wer...
# 8  ABA number for wire transfer  113024009 In add...
# 9  I thank our overseas donors who waited patient...

# %%
def clearText(text):
    text = re.sub(r'&amp;+','',text)
    text = re.sub(r'#','',text)
    text = re.sub(r'https?:\/\/\S+','',text)
    
    return text

en_tweets["Tweets"] = en_tweets['tweet'].apply(clearText)

en_tweets
# Out:
# C:\Users\munir\AppData\Local\Temp/ipykernel_8516/1431495316.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_tweets["Tweets"] = en_tweets['tweet'].apply(clearText)
#                                                 tweet  \
# 2   Above all they have given themselves immunity ...
# 3   Mianwali getting ready for the million people ...
# 5   While our Ehsaas social welfare programmes wer...
# 8   ABA number for wire transfer  113024009 In add...
# 9   I thank our overseas donors who waited patient...
# 13  I also want to thank millions of donors &amp; ...
# 14  as well as our diagnostic centres in Karachi &...
# 15  I am delighted to announce that Shaukat Khanum...
# 17  Congratulations to Crown Prince Mohammed bin S...
# 19  Tragic army heli crash in which 6 soldiers wer...
# 21  Crime Minister discussing appt of COAS &amp; a...
# 23  Thank you Chakwal for the record turnout today...
# 26  including three barrages conserving 270 bn lit...
# 27  Work is progressing on Ravi city. With $40 bn ...
# 30  @CBDPunjab tasked with converting dead capital...
# 31  Pak’s 1st central business district, @CBDPunja...
# 33  Charsadda jalsa today where once again a sea o...
# 35  What we left behind &amp; how the Imported Gov...
# 39  Imported govt is completely directionless. The...
#
#                                                Tweets
# 2   Above all they have given themselves immunity ...
# 3   Mianwali getting ready for the million people ...
# 5   While our Ehsaas social welfare programmes wer...
# 8   ABA number for wire transfer  113024009 In add...
# 9   I thank our overseas donors who waited patient...
# 13  I also want to thank millions of donors  suppo...
# 14  as well as our diagnostic centres in Karachi  ...
# 15  I am delighted to announce that Shaukat Khanum...
# 17  Congratulations to Crown Prince Mohammed bin S...
# 19  Tragic army heli crash in which 6 soldiers wer...
# 21  Crime Minister discussing appt of COAS  any ot...
# 23  Thank you Chakwal for the record turnout today...
# 26  including three barrages conserving 270 bn lit...
# 27  Work is progressing on Ravi city. With $40 bn ...
# 30  @CBDPunjab tasked with converting dead capital...
# 31  Pak’s 1st central business district, @CBDPunja...
# 33  Charsadda jalsa today where once again a sea o...
# 35  What we left behind  how the Imported Govt, br...
# 39  Imported govt is completely directionless. The...

# %%
en_tweets = pd.DataFrame(en_tweets)
en_tweets.head(5)
# Out:
#                                                tweet  \
# 2  Above all they have given themselves immunity ...
# 3  Mianwali getting ready for the million people ...
# 5  While our Ehsaas social welfare programmes wer...
# 8  ABA number for wire transfer  113024009 In add...
# 9  I thank our overseas donors who waited patient...
#
#                                               Tweets
# 2  Above all they have given themselves immunity ...
# 3  Mianwali getting ready for the million people ...
# 5  While our Ehsaas social welfare programmes wer...
# 8  ABA number for wire transfer  113024009 In add...
# 9  I thank our overseas donors who waited patient...

# %%
from textblob import TextBlob
from wordcloud import WordCloud
def getsubjectivity(text):
    return TextBlob(text).sentiment.subjectivity
def getpopularity(text):
    return TextBlob(text).sentiment.polarity

en_tweets['Subjectivity'] = en_tweets['Tweets'].apply(getsubjectivity)
en_tweets['Polarity'] = en_tweets['Tweets'].apply(getpopularity)

# %%
en_tweets.head(5)
# Out:
#                                                tweet  \
# 2  Above all they have given themselves immunity ...
# 3  Mianwali getting ready for the million people ...
# 5  While our Ehsaas social welfare programmes wer...
# 8  ABA number for wire transfer  113024009 In add...
# 9  I thank our overseas donors who waited patient...
#
#                                               Tweets  Subjectivity  Polarity
# 2  Above all they have given themselves immunity ...      0.100000  0.150000
# 3  Mianwali getting ready for the million people ...      0.625000  0.425000
# 5  While our Ehsaas social welfare programmes wer...      0.333333 -0.053333
# 8  ABA number for wire transfer  113024009 In add...      0.184848  0.045455
# 9  I thank our overseas donors who waited patient...      0.000000  0.000000

# %% [markdown]
# ### Bag of words

# %%
all_word = ' '.join([twts for twts in en_tweets['Tweets']])
wordCloud = WordCloud(width = 500, height = 300,random_state = 21, max_font_size = 119).generate(all_word)

plt.imshow(wordCloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Netural'
    else:
        return 'Positive'
    
en_tweets['Analysis'] = en_tweets['Polarity'].apply(getAnalysis)
en_tweets
# Out:
#                                                 tweet  \
# 2   Above all they have given themselves immunity ...
# 3   Mianwali getting ready for the million people ...
# 5   While our Ehsaas social welfare programmes wer...
# 8   ABA number for wire transfer  113024009 In add...
# 9   I thank our overseas donors who waited patient...
# 13  I also want to thank millions of donors &amp; ...
# 14  as well as our diagnostic centres in Karachi &...
# 15  I am delighted to announce that Shaukat Khanum...
# 17  Congratulations to Crown Prince Mohammed bin S...
# 19  Tragic army heli crash in which 6 soldiers wer...
# 21  Crime Minister discussing appt of COAS &amp; a...
# 23  Thank you Chakwal for the record turnout today...
# 26  including three barrages conserving 270 bn lit...
# 27  Work is progressing on Ravi city. With $40 bn ...
# 30  @CBDPunjab tasked with converting dead capital...
# 31  Pak’s 1st central business district, @CBDPunja...
# 33  Charsadda jalsa today where once again a sea o...
# 35  What we left behind &amp; how the Imported Gov...
# 39  Imported govt is completely directionless. The...
#
#                                                Tweets  Subjectivity  Polarity  \
# 2   Above all they have given themselves immunity ...      0.100000  0.150000
# 3   Mianwali getting ready for the million people ...      0.625000  0.425000
# 5   While our Ehsaas social welfare programmes wer...      0.333333 -0.053333
# 8   ABA number for wire transfer  113024009 In add...      0.184848  0.045455
# 9   I thank our overseas donors who waited patient...      0.000000  0.000000
# 13  I also want to thank millions of donors  suppo...      0.900000  0.200000
# 14  as well as our diagnostic centres in Karachi  ...      0.180556 -0.097222
# 15  I am delighted to announce that Shaukat Khanum...      0.450000  0.210000
# 17  Congratulations to Crown Prince Mohammed bin S...      0.454545  0.136364
# 19  Tragic army heli crash in which 6 soldiers wer...      0.716667  0.050000
# 21  Crime Minister discussing appt of COAS  any ot...      0.687500 -0.062500
# 23  Thank you Chakwal for the record turnout today...      0.500000  0.200000
# 26  including three barrages conserving 270 bn lit...      0.416667  0.200000
# 27  Work is progressing on Ravi city. With $40 bn ...      0.425397  0.088095
# 30  @CBDPunjab tasked with converting dead capital...      0.483333 -0.033333
# 31  Pak’s 1st central business district, @CBDPunja...      0.402778  0.055556
# 33  Charsadda jalsa today where once again a sea o...      0.500000  0.250000
# 35  What we left behind  how the Imported Govt, br...      0.350000 -0.200000
# 39  Imported govt is completely directionless. The...      0.587500  0.125000
#
#     Analysis
# 2   Positive
# 3   Positive
# 5   Negative
# 8   Positive
# 9    Netural
# 13  Positive
# 14  Negative
# 15  Positive
# 17  Positive
# 19  Positive
# 21  Negative
# 23  Positive
# 26  Positive
# 27  Positive
# 30  Negative
# 31  Positive
# 33  Positive
# 35  Negative
# 39  Positive

# %%
plt.figure(figsize=(8,6))
for i in range(0,en_tweets.shape[0]):
    plt.scatter(en_tweets['Polarity'].iloc[i],en_tweets['Subjectivity'].iloc[i],color='Blue'
               )
    
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
en_tweets['Analysis'].value_counts().plot(kind='bar')
plt.show()
