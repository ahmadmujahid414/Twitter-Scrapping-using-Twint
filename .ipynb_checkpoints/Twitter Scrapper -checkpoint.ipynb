# 4  2022-08-22 01:21:06       500    NaN
# 8  2022-08-21 22:45:53       500    NaN
# 9  2022-08-21 22:45:51       500    NaN
#
#                                                tweet language hashtags  ...  \
# 1  Strongly condemn arrest &amp; imprisonment of ...       en       []  ...
# 4  Congratulations to Mahmood Maulvi &amp; Team P...       en       []  ...
# 8  This is not only a gross violation of freedom ...       en       []  ...
# 9  The fascist Imported govt sunk to a new low to...       en       []  ...
#
#   geo  source  user_rt_id user_rt retweet_id  reply_to  retweet_date  \
# 1 NaN     NaN         NaN     NaN        NaN        []           NaN
# 4 NaN     NaN         NaN     NaN        NaN        []           NaN
# 8 NaN     NaN         NaN     NaN        NaN        []           NaN
# 9 NaN     NaN         NaN     NaN        NaN        []           NaN
#
#   translate trans_src trans_dest
# 1       NaN       NaN        NaN
# 4       NaN       NaN        NaN
# 8       NaN       NaN        NaN
# 9       NaN       NaN        NaN
#
# [4 rows x 39 columns]

# %%
english_tweets_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'conversation_id', 'created_at', 'date', 'timezone',
#        'place', 'tweet', 'language', 'hashtags', 'cashtags', 'user_id',
#        'user_id_str', 'username', 'name', 'day', 'hour', 'link', 'urls',
#        'photos', 'video', 'thumbnail', 'retweet', 'nlikes', 'nreplies',
#        'nretweets', 'quote_url', 'search', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
#        'translate', 'trans_src', 'trans_dest'],
#       dtype='object')

# %% [markdown]
# ### Tweets data Only

# %%
en_tweets = english_tweets_data[['tweet']]

# %%
en_tweets.head(5)
# Out:
#                                                 tweet
# 1   Strongly condemn arrest &amp; imprisonment of ...
# 4   Congratulations to Mahmood Maulvi &amp; Team P...
# 8   This is not only a gross violation of freedom ...
# 9   The fascist Imported govt sunk to a new low to...
# 10  After Pemra blocked live transmission of my Pi...

# %% [markdown]
# ### Using NLTK for word tokenizing and stopwords removal

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# ### Applying word_tokenizer on tweets

# %%
sents = []
for sent in en_tweets.values:
    word = word_tokenize(sent[0])
    sents.append(word)

# %%
sents
# Out:
# [['Strongly',
#   'condemn',
#   'arrest',
#   '&',
#   'amp',
#   ';',
#   'imprisonment',
#   'of',
#   'Sindh',
#   'Oppsition',
#   'leader',
#   ',',
#   'PTI',
#   "'s",
#   'Haleem',
#   'Adil',
#   'Shaikh',
#   'simply',
#   'to',
#   'silence',
#   'his',
#   'voice',
#   ',',
#   'by',
#   'the',
#   'Zardari',
#   'mafia',
#   '.',
#   'Haleem',
#   'has',
#   'a',
#   'broken',
#   'leg',
#   '&',
#   'amp',
#   ';',
#   'is',
#   'on',
#   'hunger',
#   'strike',
#   'in',
#   'jail',
#   '.',
#   'We',
#   'demand',
#   'his',
#   'immediate',
#   'release',
#   '&',
#   'amp',
#   ';',
#   'an',
#   'end',
#   'to',
#   'his',
#   'political',
#   'victimisation',
#   '&',
#   'amp',
#   ';',
#   'torture',
#   '.'],
#  ['Congratulations',
#   'to',
#   'Mahmood',
#   'Maulvi',
#   '&',
#   'amp',
#   ';',
#   'Team',
#   'PTI',
#   'Karachi',
#   'for',
#   'victory',
#   'in',
#   'the',
#   'NA',
#   '245',
#   'election',
#   'today',
#   '.',
#   'InshaAllah',
#   'we',
#   'are',
#   'moving',
#   'forward',
#   'in',
#   'our',
#   'movement',
#   'for',
#   'Haqeeqi',
#   'Azadi',
#   '.'],
#  ['This',
#   'is',
#   'not',
#   'only',
#   'a',
#   'gross',
#   'violation',
#   'of',
#   'freedom',
#   'of',
#   'speech',
#   'but',
#   'also',
#   'negatively',
#   'affects',
#   'the',
#   'digital',
#   'media',
#   'industry',
#   'and',
#   'the',
#   'livelihoods',
#   'of',
#   'many',
#   '.',
#   'What',
#   'they',
#   'need',
#   'to',
#   'understand',
#   'is',
#   'that',
#   'no',
#   'matter',
#   'what',
#   'they',
#   'do',
#   ',',
#   'they',
#   'can',
#   'not',
#   'suppress',
#   'the',
#   'will',
#   'of',
#   'the',
#   'people',
#   'which',
#   'is',
#   'Haqeeqi',
#   'Azadi',
#   '.'],
#  ['The',
#   'fascist',
#   'Imported',
#   'govt',
#   'sunk',
#   'to',
#   'a',
#   'new',
#   'low',
#   'today',
#   'by',
#   'banning',
#   'live',
#   'coverage',
#   'of',
#   'my',
#   'speeches',
#   'on',
#   'TV',
#   '&',
#   'amp',
#   ';',
#   'then',
#   'blocking',
#   'YouTube',
#   'temporarily',
#   'during',
#   'my',
#   'speech',
#   'at',
#   'Liaquat',
#   'Bagh',
#   '.',
#   'All',
#   'this',
#   'after',
#   'continuous',
#   'intimidation',
#   'of',
#   'mediapersons',
#   '&',
#   'amp',
#   ';',
#   'taking',
#   'channels',
#   'off',
#   'air',
#   'earlier',
#   '.'],
#  ['After',
#   'Pemra',
#   'blocked',
#   'live',
#   'transmission',
#   'of',
#   'my',
#   'Pindi',
#   'jalsa',
#   'speech',
#   'on',
#   'TV',
#   'channels',
#   ',',
#   'Imported',
#   'govt',
#   'blocked',
#   'YouTube',
#   'midway',
#   'through',
#   'my',
#   'speech',
#   '.',
#   'This',
#   'just',
#   'shows',
#   'the',
#   'desperation',
#   'of',
#   'those',
#   'who',
#   'for',
#   'their',
#   'self',
#   'interest',
#   'are',
#   'willing',
#   'to',
#   'push',
#   'Pakistan',
#   'towards',
#   'political',
#   'and',
#   'economic',
#   'chaos',
#   '.'],
#  ['We',
#   'are',
#   'on',
#   'our',
#   'way',
#   'to',
#   'winning',
#   'Karachi',
#   'NA',
#   '245',
#   'election',
#   '.',
#   'Our',
#   'camps',
#   'are',
#   'full',
#   'of',
#   'voters',
#   'while',
#   'opposition',
#   'camps',
#   'are',
#   'empty',
#   '.',
#   'I',
#   'am',
#   'asking',
#   'all',
#   'our',
#   'voters',
#   'to',
#   'go',
#   'immediately',
#   'to',
#   'vote',
#   'if',
#   'they',
#   'have',
#   "n't",
#   'already',
#   'done',
#   'so',
#   '.'],
#  ['The',
#   'route',
#   'has',
#   'been',
#   'altered',
#   'and',
#   'we',
#   'will',
#   'start',
#   'the',
#   'rally',
#   'from',
#   'Zero',
#   'Point',
#   'to',
#   'F9',
#   'Park',
#   'tomorrow',
#   'after',
#   'Maghrib',
#   '.'],
#  ['I',
#   'am',
#   'inviting',
#   'everyone',
#   'to',
#   'join',
#   'us',
#   'tomorrow',
#   'and',
#   'raise',
#   'their',
#   'voice',
#   'in',
#   'protest',
#   '.'],
#  ['Tomorrow',
#   'I',
#   'will',
#   'be',
#   'leading',
#   'a',
#   'rally',
#   'after',
#   'Maghrib',
#   ',',
#   'from',
#   'China',
#   'chowk',
#   'to',
#   'F9',
#   'Park',
#   ',',
#   'in',
#   'support',
#   'of',
#   'Dr',
#   'Gill',
#   '&',
#   'amp',
#   ';',
#   'in',
#   'protest',
#   'against',
#   'the',
#   'torture',
#   'inflicted',
#   'on',
#   'him',
#   '.',
#   'We',
#   'will',
#   'also',
#   'be',
#   'protesting',
#   'against',
#   'muzzling',
#   'of',
#   'Ary',
#   'simply',
#   'bec',
#   'Ary',
#   'did',
#   "n't",
#   'toe',
#   'the',
#   'official',
#   'line',
#   '&',
#   'amp',
#   ';',
#   'gave',
#   'coverage',
#   'to',
#   'our',
#   'narrative',
#   '.'],
#  ['Who',
#   'tortured',
#   'Gill',
#   '?',
#   'There',
#   'is',
#   'a',
#   'general',
#   'perception',
#   'in',
#   'the',
#   'public',
#   'at',
#   'large',
#   '&',
#   'amp',
#   ';',
#   'in',
#   'our',
#   'minds',
#   'too',
#   'as',
#   'to',
#   'who',
#   'could',
#   'have',
#   'carried',
#   'out',
#   'the',
#   'gruesome',
#   'torture',
#   '.',
#   'Remember',
#   'the',
#   'public',
#   'will',
#   'react',
#   '.',
#   'We',
#   'will',
#   'leave',
#   'no',
#   'stone',
#   'unturned',
#   'to',
#   'find',
#   'out',
#   'those',
#   'responsible',
#   '&',
#   'amp',
#   ';',
#   'bring',
#   'them',
#   'to',
#   'justice',
#   '.'],
#  ['All',
#   'the',
#   'pictures',
#   '&',
#   'amp',
#   ';',
#   'videos',
#   'show',
#   'clearly',
#   'Gill',
#   'was',
#   'tortured',
#   'both',
#   'mentally',
#   '&',
#   'amp',
#   ';',
#   'physically',
#   'incl',
#   'sexual',
#   'abuse',
#   '-',
#   'most',
#   'too',
#   'gruesome',
#   'to',
#   'relate',
#   '.',
#   'He',
#   'was',
#   'humiliated',
#   'to',
#   'break',
#   'him',
#   'down',
#   '.',
#   'I',
#   'now',
#   'have',
#   'full',
#   'detailed',
#   'info',
#   '.',
#   'ICT',
#   'police',
#   'says',
#   'it',
#   'did',
#   'not',
#   'inflict',
#   'any',
#   'torture',
#   '.',
#   'So',
#   'my',
#   'question',
#   'is',
#   ':',
#   'https',
#   ':',
#   '//t.co/iGNczYChnt'],
#  ['Meanwhile',
#   'the',
#   'likes',
#   'of',
#   'NS',
#   ',',
#   'Maryam',
#   ',',
#   'MFR',
#   ',',
#   'AZ',
#   ',',
#   'all',
#   'of',
#   'whom',
#   'have',
#   'in',
#   'the',
#   'worst',
#   'possible',
#   'way',
#   '&',
#   'amp',
#   ';',
#   'repeatedly',
#   'attacked',
#   'State',
#   'institutions',
#   'through',
#   'malicious',
#   '&',
#   'amp',
#   ';',
#   'targeted',
#   'statements',
#   'against',
#   'them',
#   ',',
#   'get',
#   'away',
#   'without',
#   'even',
#   'a',
#   'hint',
#   'of',
#   'a',
#   'reprimand',
#   '.'],
#  ['Descending',
#   'into',
#   'a',
#   'banana',
#   'republic',
#   '.',
#   'The',
#   'civilised',
#   'world',
#   'will',
#   'be',
#   'shocked',
#   'at',
#   'our',
#   'levels',
#   'of',
#   'barbarism',
#   '.',
#   'The',
#   'worst',
#   'part',
#   'is',
#   'an',
#   'easy',
#   'target',
#   'has',
#   'been',
#   'chosen',
#   'to',
#   'make',
#   'an',
#   'example',
#   'of',
#   'through',
#   'torture',
#   '&',
#   'amp',
#   ';',
#   'without',
#   'a',
#   'fair',
#   'trial',
#   '.',
#   'https',
#   ':',
#   '//t.co/BJve8kv8FN'],
#  ['but',
#   'also',
#   'any',
#   'such',
#   'extra-Constitutional',
#   '&',
#   'amp',
#   ';',
#   'extra-legal',
#   'actions',
#   'being',
#   'devised',
#   'against',
#   'us',
#   '.'],
#  ['to',
#   'target',
#   'me',
#   '&',
#   'amp',
#   ';',
#   'PTI',
#   'by',
#   'forcibly',
#   'getting',
#   'false',
#   'statements',
#   'against',
#   'us',
#   'similar',
#   'to',
#   'what',
#   'they',
#   'have',
#   'been',
#   'doing',
#   'against',
#   'social',
#   'media',
#   'activists.This',
#   'is',
#   'absolutely',
#   'unacceptable',
#   '.',
#   'We',
#   'will',
#   'take',
#   'all',
#   'legal',
#   '&',
#   'amp',
#   ';',
#   'pol',
#   'actions',
#   'to',
#   'counter',
#   'not',
#   'only',
#   'this',
#   'torture',
#   'being',
#   'inflicted',
#   'upon',
#   'Shahbaz',
#   'Gill'],
#  ['Very',
#   'concerned',
#   'about',
#   'Shahbaz',
#   'Gill',
#   'being',
#   'sent',
#   'into',
#   'police',
#   'remand',
#   'again',
#   '.',
#   'He',
#   'is',
#   'in',
#   'a',
#   'fragile',
#   'state',
#   'of',
#   'mental',
#   '&',
#   'amp',
#   ';',
#   'physical',
#   'health',
#   'because',
#   'of',
#   'the',
#   'torture',
#   'inflicted',
#   'on',
#   'him',
#   'when',
#   'he',
#   'was',
#   'abducted',
#   '&',
#   'amp',
#   ';',
#   'taken',
#   'to',
#   'undisclosed',
#   'location',
#   '&',
#   'amp',
#   ';',
#   'then',
#   'again',
#   'at',
#   'the',
#   'police',
#   'station',
#   '.',
#   'This',
#   'is',
#   'part',
#   'of',
#   'conspiracy'],
#  ['&',
#   'amp',
#   ';',
#   'myself',
#   ',',
#   'to',
#   'succeed',
#   ',',
#   'then',
#   'we',
#   'will',
#   'be',
#   'returning',
#   'to',
#   'the',
#   'dark',
#   'days',
#   'of',
#   'dictatorship',
#   'when',
#   'there',
#   'was',
#   'no',
#   'independent',
#   'media',
#   '&',
#   'amp',
#   ';',
#   'no',
#   'room',
#   'for',
#   'freedom',
#   'of',
#   'expression',
#   '.',
#   'Haqeeqi',
#   'Azadi',
#   'can',
#   'not',
#   'be',
#   'achieved',
#   'without',
#   'a',
#   'free',
#   'media',
#   '&',
#   'amp',
#   ';',
#   'freedom',
#   'of',
#   'speech',
#   'as',
#   'guaranteed',
#   'in',
#   'our',
#   'Constitution',
#   '.'],
#  ['Others',
#   'like',
#   'Imran',
#   'Riaz',
#   ',',
#   'Sami',
#   'Ibrahim',
#   ',',
#   'Ayaz',
#   'Amir',
#   'have',
#   'suffered',
#   'threats',
#   ',',
#   'violent',
#   'attacks',
#   '&',
#   'amp',
#   ';',
#   'arrest',
#   '.',
#   'In',
#   'my',
#   'mass',
#   'public',
#   'campaign',
#   'across',
#   'Pak',
#   'from',
#   'next',
#   'week',
#   ',',
#   'I',
#   'will',
#   'take',
#   'up',
#   'issue',
#   'of',
#   'media',
#   'freedom',
#   '&',
#   'amp',
#   ';',
#   'freedom',
#   'of',
#   'expression',
#   '.',
#   'If',
#   'we',
#   'allow',
#   'these',
#   'terror',
#   'tactics',
#   ',',
#   'designed',
#   'simply',
#   'to',
#   'target',
#   'PTI'],
#  ['I',
#   'want',
#   'to',
#   'warn',
#   'our',
#   'nation',
#   'of',
#   'an',
#   'unprecedented',
#   'crackdown',
#   'campaign',
#   'by',
#   'Imported',
#   'govt',
#   '&',
#   'amp',
#   ';',
#   'State',
#   'machinery',
#   'against',
#   'media',
#   'houses',
#   '&',
#   'amp',
#   ';',
#   'journalists',
#   'who',
#   'are',
#   'carrying',
#   'PTI',
#   '&',
#   'amp',
#   ';',
#   'my',
#   'narrative',
#   'to',
#   'the',
#   'public',
#   '.',
#   'Two',
#   'journalists',
#   ',',
#   'Arshad',
#   'Sharif',
#   '&',
#   'amp',
#   ';',
#   'Sabir',
#   'Shakir',
#   ',',
#   'have',
#   'had',
#   'to',
#   'leave',
#   'Pak',
#   'fearing',
#   'for',
#   'their',
#   'lives',
#   '.'],
#  ['Judiciary',
#   'needs',
#   'to',
#   'take',
#   'notice',
#   'of',
#   'this',
#   '.',
#   'Ary',
#   "'s",
#   'news',
#   'editor',
#   'was',
#   'picked',
#   'up',
#   'violently',
#   'late',
#   'night',
#   'from',
#   'his',
#   'home',
#   'without',
#   'warrant',
#   '&',
#   'amp',
#   ';',
#   'a',
#   'wife',
#   'with',
#   'suckling',
#   'baby',
#   'picked',
#   'up',
#   'illegally',
#   'bec',
#   'her',
#   'husband',
#   'worked',
#   'for',
#   'Gill',
#   '.',
#   'A',
#   'climate',
#   'of',
#   'fear',
#   'is',
#   'being',
#   'spread',
#   'to',
#   'make',
#   'ppl',
#   'kowtow',
#   'before',
#   'cabal',
#   'of',
#   'crooks',
#   '.']]

# %% [markdown]
# ### Removing Stops Words

# %%
stop_words = set(stopwords.words('english'))
filtered_sent = []
for w in sents:
    for word in w:
        if not word.lower() in stop_words:
            filtered_sent.append(word)

# %%
for word in filtered_sent:
    print(word)
# Out:
# Strongly
# condemn
# arrest
# &
# amp
# ;
# imprisonment
# Sindh
# Oppsition
# leader
# ,
# PTI
# 's
# Haleem
# Adil
# Shaikh
# simply
# silence
# voice
# ,
# Zardari
# mafia
# .
# Haleem
# broken
# leg
# &
# amp
# ;
# hunger
# strike
# jail
# .
# demand
# immediate
# release
# &
# amp
# ;
# end
# political
# victimisation
# &
# amp
# ;
# torture
# .
# Congratulations
# Mahmood
# Maulvi
# &
# amp
# ;
# Team
# PTI
# Karachi
# victory
# NA
# 245
# election
# today
# .
# InshaAllah
# moving
# forward
# movement
# Haqeeqi
# Azadi
# .
# gross
# violation
# freedom
# speech
# also
# negatively
# affects
# digital
# media
# industry
# livelihoods
# many
# .
# need
# understand
# matter
# ,
# suppress
# people
# Haqeeqi
# Azadi
# .
# fascist
# Imported
# govt
# sunk
# new
# low
# today
# banning
# live
# coverage
# speeches
# TV
# &
# amp
# ;
# blocking
# YouTube
# temporarily
# speech
# Liaquat
# Bagh
# .
# continuous
# intimidation
# mediapersons
# &
# amp
# ;
# taking
# channels
# air
# earlier
# .
# Pemra
# blocked
# live
# transmission
# Pindi
# jalsa
# speech
# TV
# channels
# ,
# Imported
# govt
# blocked
# YouTube
# midway
# speech
# .
# shows
# desperation
# self
# interest
# willing
# push
# Pakistan
# towards
# political
# economic
# chaos
# .
# way
# winning
# Karachi
# NA
# 245
# election
# .
# camps
# full
# voters
# opposition
# camps
# empty
# .
# asking
# voters
# go
# immediately
# vote
# n't
# already
# done
# .
# route
# altered
# start
# rally
# Zero
# Point
# F9
# Park
# tomorrow
# Maghrib
# .
# inviting
# everyone
# join
# us
# tomorrow
# raise
# voice
# protest
# .
# Tomorrow
# leading
# rally
# Maghrib
# ,
# China
# chowk
# F9
# Park
# ,
# support
# Dr
# Gill
# &
# amp
# ;
# protest
# torture
# inflicted
# .
# also
# protesting
# muzzling
# Ary
# simply
# bec
# Ary
# n't
# toe
# official
# line
# &
# amp
# ;
# gave
# coverage
# narrative
# .
# tortured
# Gill
# ?
# general
# perception
# public
# large
# &
# amp
# ;
# minds
# could
# carried
# gruesome
# torture
# .
# Remember
# public
# react
# .
# leave
# stone
# unturned
# find
# responsible
# &
# amp
# ;
# bring
# justice
# .
# pictures
# &
# amp
# ;
# videos
# show
# clearly
# Gill
# tortured
# mentally
# &
# amp
# ;
# physically
# incl
# sexual
# abuse
# -
# gruesome
# relate
# .
# humiliated
# break
# .
# full
# detailed
# info
# .
# ICT
# police
# says
# inflict
# torture
# .
# question
# :
# https
# :
# //t.co/iGNczYChnt
# Meanwhile
# likes
# NS
# ,
# Maryam
# ,
# MFR
# ,
# AZ
# ,
# worst
# possible
# way
# &
# amp
# ;
# repeatedly
# attacked
# State
# institutions
# malicious
# &
# amp
# ;
# targeted
# statements
# ,
# get
# away
# without
# even
# hint
# reprimand
# .
# Descending
# banana
# republic
# .
# civilised
# world
# shocked
# levels
# barbarism
# .
# worst
# part
# easy
# target
# chosen
# make
# example
# torture
# &
# amp
# ;
# without
# fair
# trial
# .
# https
# :
# //t.co/BJve8kv8FN
# also
# extra-Constitutional
# &
# amp
# ;
# extra-legal
# actions
# devised
# us
# .
# target
# &
# amp
# ;
# PTI
# forcibly
# getting
# false
# statements
# us
# similar
# social
# media
# activists.This
# absolutely
# unacceptable
# .
# take
# legal
# &
# amp
# ;
# pol
# actions
# counter
# torture
# inflicted
# upon
# Shahbaz
# Gill
# concerned
# Shahbaz
# Gill
# sent
# police
# remand
# .
# fragile
# state
# mental
# &
# amp
# ;
# physical
# health
# torture
# inflicted
# abducted
# &
# amp
# ;
# taken
# undisclosed
# location
# &
# amp
# ;
# police
# station
# .
# part
# conspiracy
# &
# amp
# ;
# ,
# succeed
# ,
# returning
# dark
# days
# dictatorship
# independent
# media
# &
# amp
# ;
# room
# freedom
# expression
# .
# Haqeeqi
# Azadi
# achieved
# without
# free
# media
# &
# amp
# ;
# freedom
# speech
# guaranteed
# Constitution
# .
# Others
# like
# Imran
# Riaz
# ,
# Sami
# Ibrahim
# ,
# Ayaz
# Amir
# suffered
# threats
# ,
# violent
# attacks
# &
# amp
# ;
# arrest
# .
# mass
# public
# campaign
# across
# Pak
# next
# week
# ,
# take
# issue
# media
# freedom
# &
# amp
# ;
# freedom
# expression
# .
# allow
# terror
# tactics
# ,
# designed
# simply
# target
# PTI
# want
# warn
# nation
# unprecedented
# crackdown
# campaign
# Imported
# govt
# &
# amp
# ;
# State
# machinery
# media
# houses
# &
# amp
# ;
# journalists
# carrying
# PTI
# &
# amp
# ;
# narrative
# public
# .
# Two
# journalists
# ,
# Arshad
# Sharif
# &
# amp
# ;
# Sabir
# Shakir
# ,
# leave
# Pak
# fearing
# lives
# .
# Judiciary
# needs
# take
# notice
# .
# Ary
# 's
# news
# editor
# picked
# violently
# late
# night
# home
# without
# warrant
# &
# amp
# ;
# wife
# suckling
# baby
# picked
# illegally
# bec
# husband
# worked
# Gill
# .
# climate
# fear
# spread
# make
# ppl
# kowtow
# cabal
# crooks
# .

# %% [markdown]
# ## Using Spacy to apply NER and Lematization

# %%
import spacy
import re

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = ""
for w in filtered_sent:
    text= text + w + " "

text2 = ""
for i in re.findall("[a-zA-Z]*",text):
    if i != "":
        text2 = text2+i + " "

# %%
doc = nlp(text2)
label = [(X.text,X.label_) for X in doc.ents]
df4 = pd.DataFrame(label,columns = ['Word','Entity'])
df5 = df4[df4['Entity'] == "ORG"]
df6 = df5['Word'].value_counts()

# %% [markdown]
# ### Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
V_data = df6
plt.figure(figsize =(10,5))
sns.barplot(V_data.values,V_data.index,alpha=0.8)
plt.title("Top Organization Mentioned")
plt.ylabel("Words from Tweets",fontsize=12)
plt.xlabel('Word Counts',fontsize=12)
plt.show()
# Out:
# C:\Users\munir\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
